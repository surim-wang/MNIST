# %%
import tensorflow as tf
import pandas as pd

# %%
(독립, 종속), _ = tf.keras.datasets.mnist.load_data()
종속 = pd.get_dummies(종속)
print(독립.shape, 종속.shape)
# Out:
# (60000, 28, 28) (60000, 10)

# %%
X = tf.keras.layers.Input(shape=[28, 28])
H = tf.keras.layers.Flatten()(X)
H = tf.keras.layers.Dense(84, activation = 'swish')(H)
Y = tf.keras.layers.Dense(10, activation = 'softmax')(H)

model = tf.keras.models.Model(X, Y)
model.compile(loss='categorical_crossentropy', metrics='accuracy')

# %%
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.5413 - accuracy: 0.8575
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5329 - accuracy: 0.9169
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4431 - accuracy: 0.9326
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3954 - accuracy: 0.9397
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3736 - accuracy: 0.9426
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3744 - accuracy: 0.9452
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3674 - accuracy: 0.9488
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3602 - accuracy: 0.9507
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3468 - accuracy: 0.9512
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3288 - accuracy: 0.9516

# %%
X = tf.keras.layers.Input(shape=[28, 28])
H = tf.keras.layers.Flatten()(X)
print(H)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), name='flatten/Reshape:0', description="created by layer 'flatten'")
